# %% [markdown]
# # Introduction to Matplotlib

# %% [markdown]
# <img src="anatomy-of-matplot-lib.png" />

# %%
# Import all neccessary tools
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pyplot API

# %%
# Plotting
plt.plot()
plt.show()

# %%
plt.plot();

# %%
plt.plot([1, 3, 4, 6]);

# %%
x = [1, 2, 3, 4]
y = [21, 3, 22, 90]
plt.plot(x, y);

# %% [markdown]
# ## Object Oriented API (More flexible than pyplot)

# %%
# 1st Method
fig = plt.figure() # Creates a figure
ax = fig.add_subplot() # Add some axes
plt.show()

# %%
# 2nd method
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
# ax = fig.add_subplot() # Add some axes
ax.plot(x, y); #add some data
# plt.show()

# %%
# 3rd Method ** Recommended**

fig, ax = plt.subplots()
ax.plot(x, y);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib Workflow

# %%
# 0. Import matplot lib
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 12, 13, 14]

# 3 Setup plot
fig, ax = plt.subplots(figsize=(5, 5))

# 3. Plot data
ax.plot(x, y)

# 4 Customize plot
ax.set(title=" Simple Plot",
      xlabel="X- Axis",
      ylabel="Y-Axis")

# 5 Save & show (you save the whole figure)
fig.savefig("plot-1.png")

# %% [markdown]
# ## Making figure with Numpy Arrays
#
# We are creating:
#     Line Plot
#     Scatter Plot
#     Bar Plot
#     Histogram
#     Subplot

# %%
# Generate data
x = np.linspace(1, 10, 100)
x[:10]
# Out:
# array([1.        , 1.09090909, 1.18181818, 1.27272727, 1.36363636,
#        1.45454545, 1.54545455, 1.63636364, 1.72727273, 1.81818182])

# %%
# Create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use same data to create scatter
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from a Dictionary
nut_butter_prices = {
    "Almond Butter": 10,
    "Peanut Butter": 15,
    "Cashew: Butter": 4
}

fig, ax = plt.subplots();
ax.set(title="Prices of nut butters", xlabel="Butters", ylabel="Prices")
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
ax.set(title="Prices of nut butters in horizontal manner graph");

# %% [markdown]
# ### Histogram

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two Options for subplots

# %% [markdown]
# ### Option 1

# %%
# Subplot option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(10, 5))
# Plot each axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %% [markdown]
# ### Option 2

# %%
## Subplots option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10, 5))
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(20), np.random.random(20))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from Pandas DataFrame

# %%
# Make a data frame
car_sales = pd.read_csv("car-sales.csv");
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Plotting from Pandas Series

# %%
ts = pd.Series(np.random.randn(1000), 
              index=pd.date_range("06/11/2020", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', "")
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("10/06/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-10-06
# 1   Honda    Red          87899      4   5000 2020-10-07
# 2  Toyota   Blue          32549      3   7000 2020-10-08
# 3     BMW  Black          11179      5  22000 2020-10-09
# 4  Nissan  White         213095      4   3500 2020-10-10
# 5  Toyota  Green          99213      4   4500 2020-10-11
# 6   Honda   Blue          45698      4   7500 2020-10-12
# 7   Honda   Blue          54738      4   7000 2020-10-13
# 8  Toyota  White          60000      4   6250 2020-10-14
# 9  Nissan  White          31600      4   9700 2020-10-15

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-10-06         4000
# 1   Honda    Red          87899      4   5000 2020-10-07         9000
# 2  Toyota   Blue          32549      3   7000 2020-10-08        16000
# 3     BMW  Black          11179      5  22000 2020-10-09        38000
# 4  Nissan  White         213095      4   3500 2020-10-10        41500
# 5  Toyota  Green          99213      4   4500 2020-10-11        46000
# 6   Honda   Blue          45698      4   7500 2020-10-12        53500
# 7   Honda   Blue          54738      4   7000 2020-10-13        60500
# 8  Toyota  White          60000      4   6250 2020-10-14        66750
# 9  Nissan  White          31600      4   9700 2020-10-15        76450

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
car_sales.plot.scatter(x="Odometer (KM)", y="Price");

# %%
# Genenrate randome data
x = np.random.rand(10, 4)
# Convert random data to Pandas DataFrame
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.607246  0.716312  0.733482  0.967280
# 1  0.780962  0.519475  0.250692  0.950565
# 2  0.489670  0.969319  0.999775  0.225841
# 3  0.296614  0.390335  0.353867  0.751138
# 4  0.414381  0.361731  0.063796  0.194050
# 5  0.954455  0.604468  0.361114  0.095329
# 6  0.624859  0.613495  0.714880  0.355354
# 7  0.107418  0.162587  0.672177  0.514574
# 8  0.481234  0.427339  0.473822  0.319490
# 9  0.783208  0.999550  0.426113  0.749158

# %%
df.plot.bar();

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=50);

# %%
# Trying another dataset
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease.plot.hist();

# %%
heart_disease.plot.hist(subplots=True);
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %% [markdown]
# # Which one should we use? (pyplot vs matplotlib OO method)
# * pyplot - Okay when plotting something quickly
# * OO Method - When plotting something advanced

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
# len(over_50)
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method
over_50.plot(x="age", 
             y="chol", 
             kind="scatter", 
             c="target");

# %%
## OO method mixed with pyplot method
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(x="age", 
             y="chol", 
             kind="scatter", 
             c="target",
            ax=ax);
# ax.set_xlim([45, 100])
# Out:
# (45.0, 100.0)

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))
# plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

# Adding labels and title
ax.set(title="Heart Diseases & Cholesterol Levels", 
       xlabel="Age", 
       ylabel="Cholesterol");

# Adding legends
ax.legend(*scatter.legend_elements(), title="Target")
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
## Subplots of chol, age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10, 10),
                             sharex=True)
# Add data to ax0
ax0.scatter(x=over_50["age"], 
            y=over_50["chol"], 
            c=over_50["target"])

# Customize ax0
ax0.set(title="Heart Disease and Cholesterols Levels",
       ylabel="Cholestrol")

# Add legends to ax0
ax0.legend(*scatter.legend_elements(),
           title="Target")

# Add mean ine to ax0
ax0.axhline(over_50["chol"].mean(), 
           linestyle="--")

# Add data to ax1
ax1.scatter(x=over_50["age"],
          y=over_50["thalach"],
          c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age", # The whole figure shares this label across axeses
       ylabel="Max Heart Rate")

# Add legend to ax1
ax1.legend(*scatter.legend_elements(),
          title="Target")

ax1.axhline(over_50["thalach"].mean(),
           linestyle="--")

# Add title to figure
fig.suptitle("Heart Disease Analysis", fontsize="16", fontweight="bold");

# %% [markdown]
# ## Getting stylish with matplotlib plots

# %%
# See available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-10-06         4000
# 1   Honda    Red          87899      4   5000 2020-10-07         9000
# 2  Toyota   Blue          32549      3   7000 2020-10-08        16000
# 3     BMW  Black          11179      5  22000 2020-10-09        38000
# 4  Nissan  White         213095      4   3500 2020-10-10        41500

# %%
car_sales["Price"].astype(int).plot();

# %%
plt.style.use("seaborn-whitegrid")

# %%
car_sales["Price"].astype(int).plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn")

# %%
car_sales["Price"].astype(int).plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use("ggplot");

# %%
car_sales["Odometer (KM)"].plot();

# %%
x = np.random.randn(10, 4)
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  2.661418  0.304533 -0.039131  1.600929
# 1  0.320846  0.888666  0.768103 -0.725263
# 2 -1.127866  0.548237  1.315308 -0.329479
# 3 -0.250956  0.925029  1.008557  0.027909
# 4  0.257932  1.927075  0.698226 -1.676458
# 5 -0.105623 -1.539649 -1.821791  0.505807
# 6 -0.369150  0.622689 -1.701607  0.863240
# 7  1.265294  0.431151  1.097602 -0.176890
# 8  0.137578 -0.795331  0.236971 -0.370710
# 9 -0.503898  0.081876 -0.801106 -1.157037

# %%
ax = df.plot(kind="bar")
type(ax);

# %%
# Customizing plot with set method
ax =  df.plot(kind="bar")
ax.set(title="Random number graph from DataFrame",
      xlabel="Row Number",
      ylabel="Random Number")
ax.legend().set_visible(True)

# %%
# Set the style
plt.style.use("seaborn-whitegrid")

## OO method from scratch
fig, ax = plt.subplots(figsize=(10, 6))
# plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="winter") # Changes the color scheme

# Adding labels and title
ax.set(title="Heart Diseases & Cholesterol Levels", 
       xlabel="Age", 
       ylabel="Cholesterol");

# Adding legends
ax.legend(*scatter.legend_elements(), title="Target")
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
# Customizing x and y axis limitations

## Subplots of chol, age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10, 10),
                             sharex=True)
# Add data to ax0
ax0.scatter(x=over_50["age"], 
            y=over_50["chol"], 
            c=over_50["target"],
           cmap="winter")

# Customize ax0
ax0.set(title="Heart Disease and Cholesterols Levels",
       ylabel="Cholestrol")

# Change x axis limit
ax0.set_xlim([50, 80])
ax0.set_ylim([60, 200])

# Add legends to ax0
ax0.legend(*scatter.legend_elements(),
           title="Target")

# Add mean ine to ax0
ax0.axhline(over_50["chol"].mean(), 
           linestyle="--")

# Add data to ax1
ax1.scatter(x=over_50["age"],
          y=over_50["thalach"],
          c=over_50["target"],
           cmap="winter")

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age", # The whole figure shares this label across axeses
       ylabel="Max Heart Rate")

# Add legend to ax1
ax1.legend(*scatter.legend_elements(),
          title="Target")

ax1.axhline(over_50["thalach"].mean(),
           linestyle="--")

# Add title to figure
fig.suptitle("Heart Disease Analysis", fontsize="16", fontweight="bold");
